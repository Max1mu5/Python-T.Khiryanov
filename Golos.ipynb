# %% [markdown]
# <a href="https://colab.research.google.com/github/Max1mu5/Python-T.Khiryanov/blob/master/Golos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers

# %%
# !apt-get update && apt-get install -y libsndfile1 ffmpeg
# !sudo apt-get install sox libsox-fmt-mp3
# !pip install Cython
# !pip install folium==0.2.1
# !pip install imgaug==0.2.5
# !pip install nemo_toolkit['asr']
# !pip install nemo_toolkit

# %%
# !pip3 install --upgrade pip setuptools
# %cd /content/drive/MyDrive/Fine-tune_golos/NVIDIA/apex
# !pip install -v --disable-pip-version-check --no-cache-dir ./

# %%
# %cd /content/drive/MyDrive/Fine-tune_golos
# !ls

# %%
# !apt-get update && apt-get install -y libsndfile1 ffmpeg
# !pip install Cython
# !pip install nemo_toolkit['all']

# %%
#python infer.py QuartzNet15x5_golos.nemo manifest.jsonl

# %%
#python train.py --model_config="quartznet15x5-fa.yaml" --train_dataset="/content/drive/MyDrive/Data/ru/cv-corpus-6.1-2020-12-11/ru/train.json" --eval_datasets="/content/drive/MyDrive/Data/ru/cv-corpus-6.1-2020-12-11/ru/dev.json" --batch_size=32 --num_epochs=100--checkpoint_dir='/content/drive/MyDrive/Fine-tune golos/checkpoint'

# %%
# !ls
# Out:
#  checkpoint			  Golos.ipynb	   QuartzNet15x5_golos.nemo
#  configs			  infer.py	   quartznet15x5-ru.yaml
#  convert_tsvs_to_manifest_ru.py   manifest.jsonl   TL.py
#  Data				  NVIDIA	  'Untitled Folder'
#  FT.py				  __pycache__	   wavs

# %%
# !python FT.py \
    --config-path=/content/drive/MyDrive/Fine-tune_golos/configs \
    --config-name=conf \
    trainer.max_epochs=10
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# [NeMo W 2021-06-29 14:54:18 experimental:28] Module <class 'nemo.collections.asr.data.audio_to_text_dali.AudioToCharDALIDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo I 2021-06-29 14:54:19 FT:65] Hydra config: name: QuartzNet15x5
#     model:
#       sample_rate: 16000
#       repeat: 5
#       dropout: 0.0
#       separable: true
#       labels:
#       - ' '
#       - а
#       - б
#       - в
#       - г
#       - д
#       - е
#       - ё
#       - ж
#       - з
#       - и
#       - й
#       - к
#       - л
#       - м
#       - н
#       - о
#       - п
#       - р
#       - с
#       - т
#       - у
# ...

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# [NeMo W 2021-06-29 15:13:28 experimental:28] Module <class 'nemo.collections.asr.data.audio_to_text_dali.AudioToCharDALIDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2021-06-29 15:13:29 modelPT:138] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: train/golos_and_mcv.jsonl
#     sample_rate: 16000
#     labels:
#     - ' '
#     - а
#     - б
#     - в
#     - г
#     - д
#     - е
#     - ж
#     - з
#     - и
#     - й
#     - к
#     - л
# ...
